# %%
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# <ipython-input-2-f41ff44e92b1> in <module>()
#       1 import turtle
#       2
# ----> 3 painter = turtle.Turtle()
#       4
#       5 painter.pencolor("blue")
#
# /home/anurag/anaconda3/lib/python3.5/turtle.py in __init__(self, shape, undobuffersize, visible)
#    3814                            shape=shape,
#    3815                            undobuffersize=undobuffersize,
# -> 3816                            visible=visible)
#    3817
#    3818 Pen = Turtle
#
# /home/anurag/anaconda3/lib/python3.5/turtle.py in __init__(self, canvas, shape, undobuffersize, visible)
#    2555         self._undobuffersize = undobuffersize
#    2556         self.undobuffer = Tbuffer(undobuffersize)
# -> 2557         self._update()
#    2558
#    2559     def reset(self):
#
# /home/anurag/anaconda3/lib/python3.5/turtle.py in _update(self)
# ...
